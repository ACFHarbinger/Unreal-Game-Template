# %% [markdown]
# # Polyglot App Data Analysis & Integration
#
# This notebook demonstrates how to set up the repository home directory, import modules from the Python source, and run a data analysis.

# %% [markdown]
# ## 1. Setup Environment
#
# We use the local `notebook_setup.py` utility to configure paths.

# %%
import notebook_setup
home_dir = notebook_setup.setup_home_directory("data_analysis_notebook")
print("Home directory path established:", home_dir)

# %% [markdown]
# ## 2. Import and Run Workspace Code
#
# Now that the home directory is added to the system path, we can import from `python.src.main` directly.

# %%
from python.src.main import greet

greeting = greet("Jupyter User")
print(greeting)

# %% [markdown]
# ## 3. Data Processing and Analysis
#
# Let's run a quick numerical analysis using NumPy and Pandas.

# %%
import numpy as np
import pandas as pd

# Create sample timeseries data
dates = pd.date_range("20260801", periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
print(df.describe())
