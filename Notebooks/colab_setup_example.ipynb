# %% [markdown]
# # Google Colab Setup Example
#
# This notebook demonstrates how to set up the Google Colab environment using the repository utilities.

# %%
import notebook_setup
in_colab, drive, files = notebook_setup.setup_google_colab("colab_example")
print("Running in Google Colab:", in_colab)
